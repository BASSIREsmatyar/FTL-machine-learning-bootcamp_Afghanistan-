# %% [markdown]
# # Assignment: BMI Calculator and Health Assessment

# %% [markdown]
# **Objective**: Build a Python program that calculates the Body Mass Index (BMI) of a user and provides a health assessment based on their BMI value.
#
# **Background Context**: BMI is a measure used to determine whether a person has a healthy body weight for a person of their height. It is calculated using the following formula:
#
# Formul: BMI= weight (kg) / height (m) ^  2

# %%
# my BMI calcuation 
my_weight = 78.4 #kg
my_height = 1.76 #m
BMI = my_weight/ my_height**2
print(BMI)
# Out:
# 25.309917355371905

# %%
# interpretation based on the BIM standard health assessment
if BMI < 18.5:
    print(f"My BMI is {BMI:.2f}, I'm underweight.")
elif 18.5 <= BMI <= 24.9:
    print(f"My BMI is {BMI:.2f}, I'm normal weight.")
elif 25 <= BMI <= 29.9:
    print(f"My BMI is {BMI:.2f}, I'm overweight.")
else:
    print(f"My BMI is {BMI:.2f}, I'm obese. 🥱")
# Out:
# My BMI is 25.31, I'm overweight.
